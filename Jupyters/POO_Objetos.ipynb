# %% [markdown]
# Los **Objetos** son aquellos que tienen propiedades y comportamientos, también serán sustantivos.
#
# Pueden ser Físicos o Conceptuales
#
# Las **Propiedades** también pueden llamarse **atributos** y estos también serán sustantivos. Algunos atributos o propiedades son nombre, tamaño, forma, estado, etc. Son todas **las características del objeto**.
# Los **Comportamientos** serán todas las **operaciones** que el objeto puede hacer, suelen ser verbos o sustantivos y verbo. Algunos ejemplos pueden ser que el usuario pueda hacer login y logout.

# %% [markdown]
# Una **Clase** es el **modelo** por el cual nuestros objetos se van a construir y nos van a permitir **generar más objetos**.
#
# Analizamos Objetos para crear Clases. Las Clases son los modelos sobres los cuales construiremos nuestros objetos.
#
# **Abstracción** es cuando separamos los **datos de un objeto** para generar un **molde**.

# %% [markdown]
# La **modularidad** va muy relacionada con las clases y es un principio de la Programación Orientado a Objetos y va de la mano con el **Diseño Modular** que significa **dividir un sistema en partes pequeñas** y estas serán nuestros módulos pudiendo funcionar de manera independiente.
#
# La modularidad de nuestro código nos va a permitir
#
# Reutilizar
# Evitar colapsos
# Hacer nuestro código más mantenible
# Legibilidad
# Resolución rápida de problemas
# Una buena práctica es **separando las clases en archivos diferentes**.

# %% [markdown]
# ![modularidad en POO.PNG](data:image/png;base64,...)

# %% [markdown]
# **Objetos en UBER**

# %% [markdown]
# ![Objetos en uber.PNG](data:image/png;base64,...)

# %% [markdown]
# Como definir una clase en Python, Java, JavaScript y PHP:
#
# ![Definir clases en python y mas - POO.PNG](data:image/png;base64,...)

# %% [markdown]
#   Luego de definir la clase, debo definir sus propiedades o atributos y luego sus comportamientos o operaciones. Y eso lo hago de la siguiente manera:

# %% [markdown]
# ![Definir clases en python y mas - POO 2.PNG](data:image/png;base64,...)

# %% [markdown]
# **Don’t repeat yourself** (DRY) es una filosofía que promueve la reducción de duplicación en programación, esto nos va a inculcar que no tengamos líneas de código duplicadas.
#
# Toda pieza de información nunca debería ser duplicada debido a que incrementa la dificultad en los cambios y evolución
#
# **La herencia** nos permite crear nuevas clases a partir de otras, se basa en modelos y conceptos de la vida real. También tenemos una jerarquía de padre e hijo.

# %% [markdown]
# ![Herencia, Clase y Subclase.PNG](data:image/png;base64,...)

# %% [markdown]
# Por ejemplo si tengo estas tres clases donde se repiten atributos y comportamientos varios:

# %% [markdown]
# ![11111.PNG](data:image/png;base64,...)

# %% [markdown]
# Puedo abstraerlas y sacar a una clase padre todo lo que se repite. Dejando las subclases con lo que distingue a cada una de ellas:

# %% [markdown]
# ![22222.PNG](data:image/png;base64,...)

# %% [markdown]
# En python para comenzar a programar nuestro diagrama de clases de forma modularizada primero debemos grabar un archivo setting.json donde vamos a especificar donde debe buscar python nuestros modulos
# Luego debemos dentro de la carpeta principal de python armar un archivo main que contenga el entry point y un programa. Por ej el "Hola mundo". Finalmente vamos a ir declarando cada clase en un archivo aparte que lleve el nombre de la clase. Recordar que las clases en Python se declaran con Mayuscula inicial y con la palabra reservada class previo al nombre. Luego de declaran sus atriburos uno por uno y despues del igual se selecciona de que tipo van a ser mediante el uso del signo =. (¿Tipado estativo?)

# %% [markdown]
# Los **objetos** nos ayudan a **crear instancia de una clase**, el objeto es el resultado de lo que modelamos, de los parámetros declarados y usaremos los objetos para que nuestras clases cobren vida.
#
# Los **métodos constructores** dan un estado inicial al objeto y podemos añadirle algunos datos al objeto mediante estos métodos. Los atributos o elementos que pasemos a través del constructor serán los datos mínimos que necesita el objeto para que pueda vivir.

# %% [markdown]
# ![crear objeto de clases en python.PNG](data:image/png;base64,...)

# %% [markdown]
# ![meodos constructores para una clase en pyhton.PNG](data:image/png;base64,...)

# %% [markdown]
# ![paso de parametros para el objeto.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Herencia.png](data:image/png;base64,...)

# %% [markdown]
# Para declarar Herencia en python debo declarar una nueva clase y como parametro de la misma colocar el nombre de la clase de la que recibe la herencia.
#
# Ejemplo:
# class Student(Person):

# %% [markdown]
# Las **clases** que estén siendo **heredades** las llamaremos **familias**.
#
# Por ej acabamos de aplicar herencia a la **familia Car**. Ahora apliquémosla a la **familia Payment**.

# %% [markdown]
# El **Encapsulamiento** es hacer que un dato sea inviolable, inalterable cuando se le asigne un modificador de acceso.

# %% [markdown]
# También es conocido con el término de **"alcance"**

# %% [markdown]
# Con el encapsulamiento o alcance uno define desde donde se puede hacer visible un parametro.
#
# En Python tenemos 3 modificadores de acceso:
#
# Public -> name
# Protected -> _address (solo accesible para la clase misma y subclases)
# Private -> __password

# %% [markdown]
# ¿Como asignar datos a los atributos privados? Con estos metodos: Getters y Setters

# %% [markdown]
# ¿¿que caso tiene encapsular, si con setter y getter se puede acceder??
#
# Se usa un encapsulado para evitar que cualquier valor sea asignado directamente a ciertas variables ya que el setter al ser un método permite agregar cualquier tipo de validaciones. Lo mismo con el getter.

# %% [markdown]
# **Polimorfismo**: Muchas formas. Poli = muchas, morfismo = formas. NO es Poliformismo
#
# Es **construir métodos con el mismo nombre pero con comportamiento diferente**

# %% [markdown]
# ![Polimorfismo POO.png](data:image/png;base64,...)

# %% [markdown]
# **Metodo es una función dentro de una clase**

# %% [markdown]
# **Poliformismo** tan solo es cambiar la estructura o el **comportamiento** de un **metodo** que proviene de una **clase padre**.

# %% [markdown]
# Fin
